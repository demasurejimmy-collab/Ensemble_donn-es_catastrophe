# %%
#Apercu du data set 

from pathlib import Path
import pandas as pd

base_dir = Path.cwd()
candidate_paths = [
    base_dir / "global_disaster_response_2018_2024.csv",
    Path(r"c:/Users/maril/Documents/Humanitarian aid/Ensemble_donn-es_catastrophe") / "global_disaster_response_2018_2024.csv",
]

data_path = next((path for path in candidate_paths if path.exists()), None)
if data_path is None:
    raise FileNotFoundError("Le fichier global_disaster_response_2018_2024.csv est introuvable.")

df = pd.read_csv(data_path)

print(df.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   date                       50000 non-null  str
#  1   country                    50000 non-null  str
#  2   disaster_type              50000 non-null  str
#  3   severity_index             50000 non-null  float64
#  4   casualties                 50000 non-null  int64
#  5   economic_loss_usd          50000 non-null  float64
#  6   response_time_hours        50000 non-null  float64
#  7   aid_amount_usd             50000 non-null  float64
#  8   response_efficiency_score  50000 non-null  float64
#  9   recovery_days              50000 non-null  int64
#  10  latitude                   50000 non-null  float64
#  11  longitude                  50000 non-null  float64
# dtypes: float64(7), int64(2), str(3)
# memory usage: 4.6 MB
# None

# %%
print(df.isnull().sum())
# Out:
# date                         0
# country                      0
# disaster_type                0
# severity_index               0
# casualties                   0
# economic_loss_usd            0
# response_time_hours          0
# aid_amount_usd               0
# response_efficiency_score    0
# recovery_days                0
# latitude                     0
# longitude                    0
# dtype: int64

# %%
print(df.head())
# Out:
#          date        country disaster_type  severity_index  casualties  \
# 0  2021-01-31         Brazil    Earthquake            5.99         111
# 1  2018-12-23         Brazil  Extreme Heat            6.53         100
# 2  2020-08-10          India     Hurricane            1.55          22
# 3  2022-09-15      Indonesia  Extreme Heat            4.55          94
# 4  2022-09-28  United States      Wildfire            3.80          64
#
#    economic_loss_usd  response_time_hours  aid_amount_usd  \
# 0         7934365.71                15.62       271603.79
# 1         8307648.99                 5.03       265873.81
# 2          765136.99                32.54        49356.49
# 3         1308251.31                 7.83       237512.88
# 4         2655864.36                21.90       188910.69
#
#    response_efficiency_score  recovery_days  latitude  longitude
# 0                      83.21             67   -30.613   -122.557
# ...

# %%
print(df.tail())
# Out:
#              date        country disaster_type  severity_index  casualties  \
# 49995  2019-05-14          Chile     Landslide            5.50          78
# 49996  2020-10-30  United States      Wildfire            7.76         165
# 49997  2019-04-27         Turkey         Flood            4.90         130
# 49998  2022-10-09         Greece   Storm Surge            3.35          82
# 49999  2023-01-12   South Africa       Drought            5.03         129
#
#        economic_loss_usd  response_time_hours  aid_amount_usd  \
# 49995         3711240.93                 8.45       305020.35
# 49996        12072842.65                 1.00       363881.25
# 49997         1805859.70                 5.14       280665.61
# 49998         3176085.56                19.22        80331.23
# 49999         2933495.70                 9.08       354096.99
#
#        response_efficiency_score  recovery_days  latitude  longitude
# 49995                      94.27             55    12.976    -25.680
# ...

# %%
df.sample(10)
# Out:
#              date     country disaster_type  severity_index  casualties  \
# 20843  2022-12-23      France      Wildfire            6.32         203
# 40039  2019-05-27  Bangladesh  Extreme Heat            4.10          13
# 35389  2023-05-10       Japan   Storm Surge            6.30         178
# 27283  2020-08-11       Chile     Hurricane            4.76         106
# 46089  2024-04-04       Chile   Storm Surge            1.36          21
# 12179  2018-01-12      Turkey     Hurricane            5.87         126
# 48483  2018-03-21      Brazil         Flood            8.74         176
# 9612   2023-08-31      Mexico     Hurricane            7.78          70
# 11175  2024-09-22      France     Hurricane            7.48         215
# 6572   2019-01-11      Mexico      Wildfire            4.88          43
#
#        economic_loss_usd  response_time_hours  aid_amount_usd  \
# 20843          114488.47                 4.90       168569.28
# ...

# %%
nb_doublons = df.duplicated().sum()
print(f"Il y a {nb_doublons} ligne(s) en double dans le dataset.")
# Out:
# Il y a 0 ligne(s) en double dans le dataset.
